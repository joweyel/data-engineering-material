# %%
import pyspark
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("test") \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/06 14:26:41 WARN Utils: Your hostname, computer-hp24, resolves to a loopback address: 127.0.1.1; using 192.168.178.155 instead (on interface wlp0s20f3)
# 26/03/06 14:26:41 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/06 14:26:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/03/06 14:26:44 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
# df_green = spark.read.parquet("../data/data/raw/green/*/*/")  # Spark 3.* Version
df_green = spark.read.option("recursiveFileLookup", "true").parquet("../data/data/raw/green/")

# %%
# Data should be correctly loaded to the dataframe
df_green.show(5)
# Out:
# +--------+--------------------+---------------------+------------------+----------+------------+------------+---------------+-------------+-----------+-----+-------+----------+------------+---------+---------------------+------------+------------+---------+--------------------+
# |VendorID|lpep_pickup_datetime|lpep_dropoff_datetime|store_and_fwd_flag|RatecodeID|PULocationID|DOLocationID|passenger_count|trip_distance|fare_amount|extra|mta_tax|tip_amount|tolls_amount|ehail_fee|improvement_surcharge|total_amount|payment_type|trip_type|congestion_surcharge|
# +--------+--------------------+---------------------+------------------+----------+------------+------------+---------------+-------------+-----------+-----+-------+----------+------------+---------+---------------------+------------+------------+---------+--------------------+
# |       2| 2019-12-18 15:52:30|  2019-12-18 15:54:39|                 N|       1.0|         264|         264|            5.0|          0.0|        3.5|  0.5|    0.5|      0.01|         0.0|     NULL|                  0.3|        4.81|         1.0|      1.0|                 0.0|
# |       2| 2020-01-01 00:45:58|  2020-01-01 00:56:39|                 N|       5.0|          66|          65|            2.0|         1.28|       20.0|  0.0|    0.0|      4.06|         0.0|     NULL|                  0.3|       24.36|         1.0|      2.0|                 0.0|
# |       2| 2020-01-01 00:41:38|  2020-01-01 00:52:49|                 N|       1.0|         181|         228|            1.0|         2.47|       10.5|  0.5|    0.5|      3.54|         0.0|     NULL|                  0.3|       15.34|         1.0|      1.0|                 0.0|
# |       1| 2020-01-01 00:52:46|  2020-01-01 01:14:21|                 N|       1.0|         129|         263|            2.0|          6.3|       21.0| 3.25|    0.5|       0.0|         0.0|     NULL|                  0.3|       25.05|         2.0|      1.0|                2.75|
# |       1| 2020-01-01 00:19:57|  2020-01-01 00:30:56|                 N|       1.0|         210|         150|            1.0|          2.3|       10.0|  0.5|    0.5|       0.0|         0.0|     NULL|                  0.3|        11.3|         1.0|      1.0|                 0.0|
# +--------+--------------------+---------------------+------------------+----------+------------+------------+---------------+-------------+-----------+-----+-------+----------+------------+---------+---------------------+------------+------------+---------+--------------------+
# only showing top 5 rows

# %% [markdown]
# **Querying the Green Taxi dataframe with SQL:**

# %%
df_green.createOrReplaceTempView("green")

# %%
df_green_revenue = spark.sql("""
SELECT
    PULocationID AS zone,
    date_trunc('hour', lpep_pickup_datetime) AS hour,

    ROUND(SUM(total_amount), 2) AS amount,
    COUNT(1) AS number_records
FROM
    green
WHERE 
    lpep_pickup_datetime >= '2020-01-01 00:00:00'
GROUP BY
    1, 2
ORDER BY
    1, 2
""")

# %%
df_green_revenue.show()
# Out:
# [Stage 4:==============>                                            (2 + 6) / 8]
# +----+-------------------+------+--------------+
# |zone|               hour|amount|number_records|
# +----+-------------------+------+--------------+
# |   1|2020-01-01 03:00:00| 155.3|             1|
# |   1|2020-01-03 05:00:00|117.39|             1|
# |   1|2020-01-26 10:00:00| 85.56|             1|
# |   1|2020-01-29 18:00:00|108.36|             1|
# |   1|2020-02-01 06:00:00|115.56|             1|
# |   1|2020-02-06 07:00:00|  98.3|             1|
# |   1|2020-02-16 07:00:00|  95.3|             1|
# |   1|2020-02-17 13:00:00|  82.3|             1|
# |   1|2020-02-26 17:00:00| 49.38|             1|
# |   1|2020-03-02 15:00:00|  88.3|             1|
# |   1|2020-03-11 12:00:00|103.56|             1|
# |   1|2020-03-12 11:00:00|  61.1|             1|
# |   1|2020-03-14 11:00:00|  16.0|             1|
# |   1|2020-03-21 17:00:00| 100.3|             1|
# |   1|2020-04-10 13:00:00| 150.3|             1|
# |   1|2020-04-23 08:00:00| 37.85|             1|
# |   1|2020-07-12 07:00:00| 79.05|             1|
# |   1|2020-07-15 06:00:00|  65.3|             1|
# |   1|2020-07-18 18:00:00| 92.55|             1|
# |   1|2020-08-16 15:00:00|  74.8|             1|
# +----+-------------------+------+--------------+
# only showing top 20 rows

# %%
df_green_revenue.repartition(20).write.parquet(
    "../data/data/report/revenue/green",
    mode="overwrite")
# Out:
# 26/03/06 14:29:36 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/03/06 14:29:37 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers

# %% [markdown]
# **Querying the Yellow Taxi dataframe with SQL:**

# %%
# df_yellow = spark.read.parquet("../data/data/raw/yellow/*/*")  # Spark 3.* Version
df_yellow = spark.read.option("recursiveFileLookup", "true").parquet("../data/data/raw/yellow/")
df_yellow.createOrReplaceTempView("yellow")

# %%
df_yellow_revenue = spark.sql("""
SELECT
    date_trunc('hour', tpep_pickup_datetime) AS hour,
    PULocationID AS zone,

    ROUND(SUM(total_amount), 2) AS amount,
    COUNT(1) AS number_records
FROM
    yellow
WHERE 
    tpep_pickup_datetime >= '2020-01-01 00:00:00'
GROUP BY
    1, 2
""")

# %%
df_yellow_revenue.repartition(20).write.parquet(
    "../data/data/report/revenue/yellow",
    mode="overwrite"
)
# Out:
# 26/03/06 14:40:55 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/03/06 14:40:57 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
# 26/03/06 14:40:58 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers

# %% [markdown]
# ### 5.4.3 Joins in Spark

# %% [markdown]
# Loading the revenue dataframes instead of redoing all computations that lead to it:

# %%
df_green_revenue = spark.read.parquet("../data/data/report/revenue/green")
df_yellow_revenue = spark.read.parquet("../data/data/report/revenue/yellow")

# %% [markdown]
# The two previously created dataframes will now be joined along the columns `hour` and `zone`:

# %%
# Renaming is required, otherwise ther would be 2 `amount` and `number_records`
df_green_revenue_tmp = df_green_revenue \
    .withColumnRenamed("amount", "green_amount") \
    .withColumnRenamed("number_records", "green_number_records")

df_yellow_revenue_tmp = df_yellow_revenue \
    .withColumnRenamed("amount", "yellow_amount") \
    .withColumnRenamed("number_records", "yellow_number_records")

# %%
df_join = df_green_revenue_tmp.join(
    df_yellow_revenue_tmp,
    on=["hour", "zone"],
    how="outer"
)

# %%
df_join.show(n=5)
# Out:
# [Stage 33:>                                                         (0 + 1) / 1]
# +-------------------+----+------------+--------------------+-------------+---------------------+
# |               hour|zone|green_amount|green_number_records|yellow_amount|yellow_number_records|
# +-------------------+----+------------+--------------------+-------------+---------------------+
# |2020-01-01 00:00:00|  38|       98.79|                   2|         NULL|                 NULL|
# |2020-01-01 00:00:00|  50|        NULL|                NULL|      4177.48|                  183|
# |2020-01-01 00:00:00|  56|       99.69|                   3|         18.1|                    2|
# |2020-01-01 00:00:00|  73|        NULL|                NULL|         17.3|                    1|
# |2020-01-01 00:00:00|  79|        NULL|                NULL|     12573.81|                  721|
# +-------------------+----+------------+--------------------+-------------+---------------------+
# only showing top 5 rows

# %%
df_join.write.parquet(
    "../data/data/report/revenue/total",
    mode="overwrite"
)
# Out:
# [Stage 49:>                                                         (0 + 8) / 9]
# 25/03/02 17:34:51 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers

# %% [markdown]
# #### Joining one large tabele and one small table

# %%
# Loading the dataframe that was just saved (to avoid recomputations)
df_join = spark.read.parquet("../data/data/report/revenue/total")

# %%
# Loading the previously downloaded taxi-zones data
df_zones = spark.read.parquet('zones/')

# %%
# Performing inner join of big taxi dataframe with small zones dataframe
df_result = df_join.join(df_zones, df_join.zone == df_zones.LocationID)

# %%
df_result \
    .drop('LocationID', 'zone') \
    .write.parquet(
        'tmp/revenue-zones', 
        mode="overwrite"
    )
# Out:
# 25/03/02 17:36:41 WARN MemoryManager: Total allocation exceeds 95.00% (1,020,054,720 bytes) of heap memory
# Scaling row group sizes to 95.00% for 8 writers
